# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL 
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=2a9b89c9cf19ebdf2a26cc4ecb319413&units=metric&q=

# %%
# run single example of query output so we can know how to create for loop correctly
city1 = cities[23]

response1 = requests.get(query_url + city).json()
response1
# Out:
# {'coord': {'lon': 92.75, 'lat': 11.67},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'model',
#  'main': {'temp': 25.77,
#   'feels_like': 25.08,
#   'temp_min': 25.77,
#   'temp_max': 25.77,
#   'pressure': 1012,
#   'humidity': 67,
#   'sea_level': 1012,
#   'grnd_level': 1012},
#  'wind': {'speed': 5.72, 'deg': 7},
#  'clouds': {'all': 67},
#  'dt': 1580018729,
#  'sys': {'country': 'IN', 'sunrise': 1579997631, 'sunset': 1580039314},
#  'timezone': 19800,
#  'id': 1259385,
#  'name': 'Port Blair',
#  'cod': 200}

# %%
# give results of a single city to check code is working
City1 = response1['name']
Cloudiness1 = response1["clouds"]["all"]
Country1 = response1['sys']['country']
Humidity1 = response1['main']['humidity']
Lat1 = response1['coord']['lat']
Lng1 = response1['coord']['lon']
Max_Temp1 = response1['main']['temp_max']
Wind_Speed1 = response1['wind']['speed']

print(City1, Cloudiness1, Country1, Humidity1, Lat1, Lng1, Max_Temp1, Wind_Speed1)
# Out:
# Port Blair 67 IN 67 11.67 92.75 25.77 5.72

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set up lists to hold reponse info
Citiesfound = []
Country = []
Cloudiness = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

counter = 0

# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    try: 
        response = requests.get(query_url + city).json()
        Citiesfound.append(response['name'])
        Country.append(response['sys']['country'])
        Cloudiness.append(response["clouds"]["all"])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_Temp.append(response['main']['temp_max'])
        Wind_Speed.append(response['wind']['speed'])
        print(f"Making request {counter} for city: {city}")
        counter = counter + 1
        #time.sleep(1.01)
    
    except: 
        print("City not found... skipping.")
# Out:
# City not found... skipping.
# Making request 0 for city: punta arenas
# Making request 1 for city: rikitea
# Making request 2 for city: bundaberg
# Making request 3 for city: santa cruz
# Making request 4 for city: qaanaaq
# Making request 5 for city: victoria
# Making request 6 for city: yarada
# Making request 7 for city: albany
# Making request 8 for city: pochutla
# City not found... skipping.
# Making request 9 for city: lata
# Making request 10 for city: ponta do sol
# Making request 11 for city: teguise
# Making request 12 for city: mataura
# Making request 13 for city: nanortalik
# Making request 14 for city: busselton
# Making request 15 for city: kaeo
# Making request 16 for city: kahului
# Making request 17 for city: matara
# Making request 18 for city: bredasdorp
# Making request 19 for city: east london
# Making request 20 for city: jamestown
# Making request 21 for city: beringovskiy
# Making request 22 for city: manta
# Making request 23 for city: kodiak
# Making request 24 for city: port alfred
# Making request 25 for city: tabou
# Making request 26 for city: ust-kuyga
# Making request 27 for city: bardiyah
# Making request 28 for city: fillmore
# Making request 29 for city: sinnamary
# Making request 30 for city: nizhniy kuranakh
# Making request 31 for city: vaini
# Making request 32 for city: ushuaia
# Making request 33 for city: klaksvik
# Making request 34 for city: butaritari
# Making request 35 for city: tasiilaq
# Making request 36 for city: georgetown
# Making request 37 for city: sao filipe
# Making request 38 for city: zhangye
# City not found... skipping.
# City not found... skipping.
# Making request 39 for city: hermanus
# Making request 40 for city: chokurdakh
# Making request 507 for city: kambove
# Making request 508 for city: miyako
# Making request 509 for city: kingseat
# Making request 510 for city: petropavlovsk-kamchatskiy
# Making request 511 for city: mindelo
# Making request 512 for city: homer
# Making request 513 for city: coahuayana
# Making request 514 for city: okha
# City not found... skipping.
# Making request 515 for city: savannah bight
# City not found... skipping.
# Making request 516 for city: sorong
# Making request 517 for city: plainview
# Making request 518 for city: kuliyapitiya
# City not found... skipping.
# Making request 519 for city: yongchang
# Making request 520 for city: general roca
# Making request 521 for city: vila
# Making request 522 for city: mineiros
# Making request 523 for city: northam
# Making request 524 for city: namibe
# Making request 525 for city: nabire
# Making request 526 for city: banjar
# Making request 527 for city: carutapera
# City not found... skipping.
# City not found... skipping.
# Making request 528 for city: yining
# City not found... skipping.
# Making request 529 for city: la roche-sur-yon
# City not found... skipping.
# Making request 530 for city: san borja
# Making request 531 for city: sydney
# Making request 532 for city: kirkwood
# Making request 533 for city: shenzhen
# Making request 534 for city: loreto
# Making request 535 for city: novo oriente
# Making request 536 for city: kudahuvadhoo
# Making request 537 for city: kastrakion
# Making request 538 for city: rio grande
# Making request 539 for city: sarangani
# Making request 540 for city: arrecife
# Making request 541 for city: kamiiso
# Making request 542 for city: pinega
# Making request 543 for city: kutulik
# City not found... skipping.
# Making request 544 for city: khuzhir
# Making request 545 for city: storforshei
# Making request 546 for city: onguday
# Making request 547 for city: liverpool
# Making request 548 for city: halifax
# Making request 549 for city: lima
# Making request 550 for city: hope
# Making request 551 for city: diego de almagro
# Making request 552 for city: vicuna
# Making request 553 for city: kandrian
# Making request 554 for city: akdepe
# Making request 555 for city: acarau
# Making request 556 for city: bonavista
# Making request 557 for city: huarmey
# Making request 558 for city: xuzhou
# Making request 559 for city: pontes e lacerda
# Making request 560 for city: ler
# Making request 561 for city: concordia
# Making request 562 for city: saldanha
# Making request 563 for city: trinidad
# Making request 564 for city: bourail
# Making request 565 for city: varhaug
# City not found... skipping.
# Making request 566 for city: san quintin
# Making request 567 for city: parrita
# Making request 568 for city: vardo
# Making request 569 for city: radhanpur
# Making request 570 for city: bandundu
# City not found... skipping.
# Making request 571 for city: mudon
# Making request 572 for city: campina verde
# Making request 573 for city: princeton
# City not found... skipping.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary, and then data frame from each variable
weather_dict = {
    "City": Citiesfound,
    "Country": Country,
    "Cloudiness": Cloudiness,
    "Humidity": Humidity,
    "Lat":Lat,
    "Lng":Lng,
    "Max Temp": Max_Temp,
    "Wind Speed": Wind_Speed
}

# Create dataframe and display
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#                         City Country  Cloudiness  Humidity    Lat     Lng  \
# 0               Punta Arenas      CL          20        70 -53.15  -70.92
# 1                    Rikitea      PF          24        78 -23.12 -134.97
# 2                  Bundaberg      AU          75        51 -24.85  152.35
# 3    Santa Cruz de la Sierra      BO          40        78 -17.80  -63.17
# 4                    Qaanaaq      GL          58        46  77.48  -69.36
# ..                       ...     ...         ...       ...    ...     ...
# 569                Radhanpur      IN           0        20  23.83   71.60
# 570                 Bandundu      CD          97        75  -3.32   17.37
# 571                    Mudon      MM          89        39  16.26   97.72
# 572            Campina Verde      BR           0        91 -19.54  -49.49
# 573                Princeton      US           1        82  25.54  -80.41
#
#      Max Temp  Wind Speed
# 0        9.00        9.30
# 1       25.96        4.96
# 2       31.11        6.70
# 3       25.00        2.60
# 4      -24.49        2.09
# ..        ...         ...
# 569     26.30        1.53
# 570     24.58        1.09
# 571     26.12        3.75
# 572     20.59        0.96
# 573     17.78        2.10
#
# [574 rows x 8 columns]

# %%
# Export to .csv 
weather_data.to_csv('../instructions/output_data/cities.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create scatter plot
plt.scatter(weather_data['Lat'], weather_data['Max Temp'], marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Add labels to the x and y axes
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Celsius)")
plt.grid()

# Save the plot and display it
plt.savefig("../instructions/Images/lat_vs_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create scatter plot
plt.scatter(weather_data['Lat'], weather_data['Humidity'], marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Add labels to the x and y axes
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

# Save the plot and display it
plt.savefig("../instructions/Images/lat_vs_hum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create scatter plot
plt.scatter(weather_data['Lat'], weather_data['Cloudiness'], marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Add labels to the x and y axes
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()

# Save the plot and display it
plt.savefig("../instructions/Images/lat_vs_cloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create scatter plot
plt.scatter(weather_data['Lat'], weather_data['Wind Speed'], marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# Add labels to the x and y axes
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (meter/sec)")
plt.grid()

# Save the plot and display it
plt.savefig("../instructions/Images/lat_vs_wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northhem = weather_data.loc[weather_data['Lat'] > 0]
print(northhem.head())

southhem = weather_data.loc[weather_data['Lat'] < 0]
print(southhem.head())
# Out:
#         City Country  Cloudiness  Humidity    Lat     Lng  Max Temp  \
# 4    Qaanaaq      GL          58        46  77.48  -69.36    -24.49
# 5  Hong Kong      HK          20        82  22.29  114.16     20.00
# 6     Yarada      IN          20        54  17.65   83.27     29.00
# 7     Albany      US          90        90  42.60  -73.97      3.33
# 8   Pochutla      MX           5        74  15.74  -96.47     26.00
#
#    Wind Speed
# 4        2.09
# 5        8.70
# 6        1.50
# 7        3.10
# 8        3.40
#                        City Country  Cloudiness  Humidity    Lat     Lng  \
# 0              Punta Arenas      CL          20        70 -53.15  -70.92
# 1                   Rikitea      PF          24        78 -23.12 -134.97
# 2                 Bundaberg      AU          75        51 -24.85  152.35
# 3   Santa Cruz de la Sierra      BO          40        78 -17.80  -63.17
# 12                  Mataura      NZ          69        61 -46.19  168.86
#
#     Max Temp  Wind Speed
# 0       9.00        9.30
# 1      25.96        4.96
# 2      31.11        6.70
# 3      25.00        2.60
# 12     20.56        4.02

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northhem['Lat']
y_values = northhem['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (Celsius)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8810146571580613

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southhem['Lat']
y_values = southhem['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (Celsius)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.3644561526728197

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northhem['Lat']
y_values = northhem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.43064355538083643

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southhem['Lat']
y_values = southhem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.28117226872181

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northhem['Lat']
y_values = northhem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.26974431216389844

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.27199402779603693

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northhem['Lat']
y_values = northhem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (meter/sec)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.1284757317858967

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southhem['Lat']
y_values = southhem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (meter/sec)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.3867268236229137
