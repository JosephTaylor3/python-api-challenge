# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
# print api key to ensure correct
g_key
# Out:
# 'AIzaSyCkdwSeOcjszNhV_1lJn0zkuihzAWtmRHs'

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Reference the file where the CSV is located
weather_path = "../output_data/cities.csv"

# Import the data into a Pandas DataFrame
weather_data = pd.read_csv(weather_path)
weather_data.head()
# Out:
#    Unnamed: 0          City Country  Cloudiness  Humidity    Lat     Lng  \
# 0           0        Shache      CN          98        97  38.42   77.24
# 1           1       Ushuaia      AR          72        96 -54.80  -68.30
# 2           2          Hilo      US          90        65  19.73 -155.09
# 3           3      Khatanga      RU          57        98  71.97  102.50
# 4           4  Punta Arenas      CL          20        70 -53.15  -70.92
#
#    Max Temp  Wind Speed
# 0      0.56        0.63
# 1      1.88        2.66
# 2     25.00        1.50
# 3    -29.85        1.36
# 4      9.00        5.70

# %%
# Remove Unnamed column
weather_data = weather_data[["City","Country","Cloudiness","Humidity","Lat","Lng","Max Temp","Wind Speed"]]
weather_data.head()
# Out:
#            City Country  Cloudiness  Humidity    Lat     Lng  Max Temp  \
# 0        Shache      CN          98        97  38.42   77.24      0.56
# 1       Ushuaia      AR          72        96 -54.80  -68.30      1.88
# 2          Hilo      US          90        65  19.73 -155.09     25.00
# 3      Khatanga      RU          57        98  71.97  102.50    -29.85
# 4  Punta Arenas      CL          20        70 -53.15  -70.92      9.00
#
#    Wind Speed
# 0        0.63
# 1        2.66
# 2        1.50
# 3        1.36
# 4        5.70

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# configure gmaps 
gmaps.configure(api_key=g_key)

# %%
# set coordinates
coordinates = weather_data[["Lat", "Lng"]].astype(float)

# convert the new DataFrame to a list that can be passed 
coordinates = coordinates.values.tolist()

Humidity_heatmap = weather_data["Humidity"].astype(float)

# Create a humidity Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(coordinates, weights=Humidity_heatmap, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# Narrow down the DataFrame to find your ideal weather condition. For example:
#
# A max temperature lower than 80 degrees but higher than 70. Wind speed less than 10 mph. Zero cloudiness.
#
# Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.
# Feel free to adjust to your specifications but be sure to limit the number of rows returned by your API requests to a reasonable number.

# %%
# My conditions:   Max temperature between 15 - 23 celsius, less than 10 % cloudiness, below 25% humidity

ideal_weather1 = weather_data.loc[(weather_data["Max Temp"] > 15) | (weather_data["Humidity"] < 25), :]

 #| (weather_data["Max Temp"] < 23) | 
#(weather_data["Cloudiness"] <= 10) | (weather_data["Humidity"] < 25)
ideal_weather1
# Out:
#                   City Country  Cloudiness  Humidity    Lat     Lng  Max Temp  \
# 2                 Hilo      US          90        65  19.73 -155.09     25.00
# 5       Port Elizabeth      ZA          20        82 -33.92   25.57     20.00
# 7               Dingle      PH          54        71  11.00  122.67     29.60
# 8               Avarua      CK         100        83 -21.21 -159.78     28.00
# 9         Kruisfontein      ZA          95        78 -34.00   24.73     16.96
# ..                 ...     ...         ...       ...    ...     ...       ...
# 541  Sao Joao da Barra      BR         100        91 -21.64  -41.05     22.39
# 542              Wajir      KE         100        68   1.75   40.06     27.65
# 543         Oranjestad      AW          20        83  12.52  -70.03     26.00
# 544      Narasannapeta      IN          29        42  18.42   84.05     29.23
# 545             Kibala      TD          49        36   9.11   18.35     17.00
#
#      Wind Speed
# ...

# %%
### Hotel Map
* Store into variable named `hotel_df`.
* Add a "Hotel Name" column to the DataFrame.
* Set parameters to search for hotels with 5000 meters.
* Hit the Google Places API for each city's coordinates.
* Store the first Hotel result into the DataFrame.
* Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display Map
